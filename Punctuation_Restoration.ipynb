# %%
# !pip install -r drive/MyDrive/punctuation-restoration-master/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 675kB 6.6MB/s
# ...
#      |████████████████████████████████| 1.2MB 10.7MB/s
# ...
#      |████████████████████████████████| 901kB 23.8MB/s
# ...
#      |████████████████████████████████| 5.6MB 34.4MB/s
# ...

# %%
#The main codeblock. Most crucial steps:
#Execute code block above
#Get github files by xashru 
#Have to have roberta-large-en.pt
#The files have to be in the connected drive
#File paths have to be accurate.
#Multiple inference files (inference, inference2, inference3, inference4)

#!python drive/MyDrive/punctuation-restoration-master/src/train.py --cuda=True --pretrained-model=roberta-large --freeze-bert=False --lstm-dim=-1 --language=english --seed=1 --lr=5e-6 --epoch=10 --use-crf=False --augment-type=all  --augment-rate=0.15 --alpha-sub=0.4 --alpha-del=0.4 --batch-size=4   --data-path=drive/MyDrive/punctuation-restoration-master/data --save-path=drive/MyDrive/punctuation-restoration-master/out
# !python drive/MyDrive/punctuation-restoration-master/src/inference.py --pretrained-model=roberta-large --weight-path=drive/MyDrive/roberta-large-en.pt --language=en --in-file=drive/MyDrive/asr_output/1_asr_output.txt --out-file=drive/MyDrive/pr_output/1_pr_output.txt
# Out:
# 2021-05-20 14:39:40.276614: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# done writing
# Punctuated text
# ...
